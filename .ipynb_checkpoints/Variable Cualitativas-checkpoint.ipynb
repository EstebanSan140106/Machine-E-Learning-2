# %% [markdown]
# <img src = "img/images.png" style="height:80px;">
# <div style="text-align:center;">
#
# # Varaibles Cualitativas
#
# <img src ="img/Python-Logo.jpg" style="height:222px;">
#
#     Marzo 30, 2026
#
# </div>
#
# ### _Esteban Sáncez_

# %%
# Creación aleatoria de datos
import numpy as np
import random
import pandas as pd
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Doctorado' 'Master' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Doctorado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Master' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado' 'Master'
#  'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Master' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Master'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Grado' 'Grado' 'Doctorado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Master' 'Doctorado' 'Secundaria' 'Doctorado' 'Master' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Master'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Master' 'Doctorado' 'Bachillerato' 'Master' 'Grado' 'Master'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Doctorado' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Master'
#  'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Secundaria'
#  'Secundaria' 'Master' 'Master' 'Doctorado' 'Secundaria' 'Secundaria'
#  'Master' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Doctorado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Grado'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Secundaria' 'Grado' 'Doctorado' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Doctorado' 'Doctorado' 'Master' 'Bachillerato' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Doctorado' 'Doctorado' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Master'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Master' 'Master' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información 
df = pd.DataFrame({
   "Nivel_Estudios":  ["Bachillerato" , "Doctorado" , "Master" , "Grado" , "Secundaria"], 
    "Frecuencia":[172, 21, 52, 145, 110 ]
})

df.plot(x="Nivel_Estudios" , y="Frecuencia", kind="bar") 
plt.title("Grafico de Barras")

plt.xlabel("Nivel de Estudios")
plt.ylabel("Frecuencia")
plt.show()

# %%
df = pd.DataFrame({
   "Nivel_Estudios":  ["Bachillerato" , "Doctorado" , "Master" , "Grado" , "Secundaria"], 
    "Frecuencia":[172, 21, 52, 145, 110 ]
})
colores = ['red', 'blue', 'orange', 'green', 'cyan']
df.plot(
    x="Nivel_Estudios",
    y="Frecuencia",
    kind="pie",
    colors=colores,
    autopct='%1.2f%%',
    labels=df["Nivel_Estudios"],
    legend=False
    )

plt.title('Diagrama de sectores')
plt.show()

# %% [markdown]
# Repositorio en GitHub: https://github.com/EstebanSan140106/Machine-E-Learning-2.git
